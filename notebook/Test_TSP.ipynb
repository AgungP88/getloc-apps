# %% [markdown]
# # TSP
#
# Several attempts to solve tsp with heuristic algorithm

# %% [markdown]
# ## Install Additional Library

# %%
pip install scikit-opt
# Out:
# Collecting scikit-opt
#   Downloading https://files.pythonhosted.org/packages/54/68/9e412721e6d14a96374fdfe6e22f251cc582900d7b9757bc7981ed163a77/scikit_opt-0.6.4-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from scikit-opt) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scikit-opt) (1.19.5)
# Installing collected packages: scikit-opt
# Successfully installed scikit-opt-0.6.4

# %%
pip install py2opt
# Out:
# Collecting py2opt
#   Downloading https://files.pythonhosted.org/packages/d4/c5/1e13b07abab90f06ccecf773955a726c23fc1fa9d75cb172ba6fc30a3af0/py2opt-1.3.2-py3-none-any.whl
# Collecting random2==1.0.1
#   Downloading https://files.pythonhosted.org/packages/ee/b5/5aca5217501fbd06b1e5aed6d5986baa0da5380880e6bb6f421ed18e3a32/random2-1.0.1.zip
# Collecting numpy==1.20.0
#   Downloading https://files.pythonhosted.org/packages/3a/6c/322f6aa128179d0ea45a543a4e29a74da2317117109899cfd56d09bf3de0/numpy-1.20.0-cp37-cp37m-manylinux2010_x86_64.whl (15.3MB)
#      |████████████████████████████████| 15.3MB 239kB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from py2opt) (3.6.4)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (1.10.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (8.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (57.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (21.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pytest->py2opt) (1.15.0)
# Building wheels for collected packages: random2
#   Building wheel for random2 (setup.py) ... done
#   Created wheel for random2: filename=random2-1.0.1-cp37-none-any.whl size=12064 sha256=cd64136aae5aceaabcca237a5455c048f8fd7169675b0c51c0be729b213e20ed
#   Stored in directory: /root/.cache/pip/wheels/36/a1/eb/8b267e15c260cf21ca104e217f46587db40eaa906cb04d37c0
# Successfully built random2
# ERROR: tensorflow 2.5.0 has requirement numpy~=1.19.2, but you'll have numpy 1.20.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: random2, numpy, py2opt
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# Successfully installed numpy-1.20.0 py2opt-1.3.2 random2-1.0.1

# %%
# !wget http://akira.ruc.dk/~keld/research/LKH-3/LKH-3.0.6.tgz
# Out:
# --2021-06-09 12:51:02--  http://akira.ruc.dk/~keld/research/LKH-3/LKH-3.0.6.tgz
# Resolving akira.ruc.dk (akira.ruc.dk)... 130.225.220.230
# Connecting to akira.ruc.dk (akira.ruc.dk)|130.225.220.230|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2312138 (2.2M) [application/x-gzip]
# Saving to: ‘LKH-3.0.6.tgz’
#
# LKH-3.0.6.tgz       100%[===================>]   2.20M  2.48MB/s    in 0.9s
#
# 2021-06-09 12:51:04 (2.48 MB/s) - ‘LKH-3.0.6.tgz’ saved [2312138/2312138]

# %%
# !tar xvfz LKH-3.0.6.tgz
# Out:
# LKH-3.0.6/
# LKH-3.0.6/pr2392.par
# LKH-3.0.6/whizzkids96.atsp
# LKH-3.0.6/Makefile
# LKH-3.0.6/whizzkids96.par
# LKH-3.0.6/pr2392.tsp
# LKH-3.0.6/DOC/
# LKH-3.0.6/README.txt
# LKH-3.0.6/SRC/
# LKH-3.0.6/SRC/Penalty_CVRPTW.c
# LKH-3.0.6/SRC/RestoreTour.c
# LKH-3.0.6/SRC/SolveKMeansSubproblems.c
# LKH-3.0.6/SRC/IsCommonEdge.c
# LKH-3.0.6/SRC/OrderCandidateSet.c
# LKH-3.0.6/SRC/CTSP_InitialTour.c
# LKH-3.0.6/SRC/AddExtraCandidates.c
# LKH-3.0.6/SRC/Distance.c
# LKH-3.0.6/SRC/Genetic.c
# LKH-3.0.6/SRC/AdjustClusters.c
# LKH-3.0.6/SRC/AddTourCandidates.c
# LKH-3.0.6/SRC/BIT.c
# LKH-3.0.6/SRC/KSwapKick.c
# LKH-3.0.6/SRC/Connect.c
# LKH-3.0.6/SRC/RemoveFirstActive.c
# LKH-3.0.6/SRC/Ascent.c
# LKH-3.0.6/SRC/TrimCandidateSet.c
# LKH-3.0.6/SRC/StatusReport.c
# LKH-3.0.6/SRC/TSPTW_Reduce.c
# LKH-3.0.6/SRC/printff.c
# LKH-3.0.6/SRC/Between_SSL.c
# LKH-3.0.6/SRC/SOP_Report.c
# LKH-3.0.6/SRC/Create_POPMUSIC_CandidateSet.c
# LKH-3.0.6/SRC/MTSP_InitialTour.c
# LKH-3.0.6/SRC/Improvement.c
# LKH-3.0.6/SRC/GeoConversion.c
# LKH-3.0.6/SRC/FindTour.c
# LKH-3.0.6/SRC/TSPTW_MakespanCost.c
# LKH-3.0.6/SRC/SymmetrizeCandidateSet.c
# LKH-3.0.6/SRC/ChooseInitialTour.c
# LKH-3.0.6/SRC/SolveKCenterSubproblems.c
# LKH-3.0.6/SRC/Penalty_1_PDTSP.c
# LKH-3.0.6/SRC/AddCandidate.c
# LKH-3.0.6/SRC/Penalty_TSPTW.c
# LKH-3.0.6/SRC/Penalty_RCTVRP.c
# LKH-3.0.6/SRC/MinimumSpanningTree.c
# LKH-3.0.6/SRC/BestSpecialOptMove.c
# LKH-3.0.6/SRC/INCLUDE/Genetic.h
# LKH-3.0.6/SRC/INCLUDE/.DS_Store
# LKH-3.0.6/SRC/INCLUDE/Segment.h
# LKH-3.0.6/SRC/INCLUDE/Delaunay.h
# LKH-3.0.6/SRC/INCLUDE/GeoConversion.h
# LKH-3.0.6/SRC/INCLUDE/LKH.h
# LKH-3.0.6/SRC/INCLUDE/BIT.h
# LKH-3.0.6/SRC/INCLUDE/Sequence.h
# LKH-3.0.6/SRC/INCLUDE/GainType.h
# LKH-3.0.6/SRC/INCLUDE/Heap.h
# LKH-3.0.6/SRC/INCLUDE/Hashing.h
# LKH-3.0.6/SRC/INCLUDE/gpx.h
# LKH-3.0.6/DOC/POPMUSIC_REPORT.pdf
# LKH-3.0.6/DOC/LKH_Genetic.pdf
# LKH-3.0.6/DOC/LKH_REPORT.pdf
# LKH-3.0.6/DOC/LKH-2_USER_GUIDE.pdf
# LKH-3.0.6/DOC/TSPLIB_DOC.pdf
# LKH-3.0.6/DOC/LKH-3_PARAMETERS.pdf
# LKH-3.0.6/DOC/LKH-3_REPORT.pdf

# %%
cd LKH-3.0.6
# Out:
# /content/LKH-3.0.6

# %%
# !make
# Out:
# make -C SRC
# make[1]: Entering directory '/content/LKH-3.0.6/SRC'
# make LKH
# make[2]: Entering directory '/content/LKH-3.0.6/SRC'
# cc -c -o OBJ/Activate.o Activate.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AddCandidate.o AddCandidate.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AddExtraCandidates.o AddExtraCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AddTourCandidates.o AddTourCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AdjustCandidateSet.o AdjustCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AdjustClusters.o AdjustClusters.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/AllocateStructures.o AllocateStructures.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Ascent.o Ascent.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Best2OptMove.o Best2OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Best3OptMove.o Best3OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Best4OptMove.o Best4OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Best5OptMove.o Best5OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/BestKOptMove.o BestKOptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/BestSpecialOptMove.o BestSpecialOptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Between.o Between.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Between_SL.o Between_SL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Between_SSL.o Between_SSL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/BridgeGain.o BridgeGain.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/BuildKDTree.o BuildKDTree.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/C.o C.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CandidateReport.o CandidateReport.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ChooseInitialTour.o ChooseInitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Connect.o Connect.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CreateCandidateSet.o CreateCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CreateDelaunayCandidateSet.o CreateDelaunayCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CreateNNCandidateSet.o CreateNNCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Create_POPMUSIC_CandidateSet.o Create_POPMUSIC_CandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CreateQuadrantCandidateSet.o CreateQuadrantCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CTSP_InitialTour.o CTSP_InitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/CVRP_InitialTour.o CVRP_InitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Delaunay.o Delaunay.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Distance.o Distance.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Distance_MTSP.o Distance_MTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Distance_SOP.o Distance_SOP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Distance_SPECIAL.o Distance_SPECIAL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/eprintf.o eprintf.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ERXT.o ERXT.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Excludable.o Excludable.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Exclude.o Exclude.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/FindTour.o FindTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/FixedOrCommonCandidates.o FixedOrCommonCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Flip.o Flip.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Flip_SL.o Flip_SL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Flip_SSL.o Flip_SSL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Forbidden.o Forbidden.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/FreeStructures.o FreeStructures.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/fscanint.o fscanint.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Gain23.o Gain23.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/GenerateCandidates.o GenerateCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Genetic.o Genetic.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/GeoConversion.o GeoConversion.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/GetTime.o GetTime.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/GreedyTour.o GreedyTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Hashing.o Hashing.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Heap.o Heap.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Improvement.o Improvement.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/IsBackboneCandidate.o IsBackboneCandidate.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/IsCandidate.o IsCandidate.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/IsCommonEdge.o IsCommonEdge.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/IsPossibleCandidate.o IsPossibleCandidate.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/KSwapKick.o KSwapKick.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# KSwapKick.c: In function ‘KSwapKick’:
# KSwapKick.c:33:5: warning: assuming signed overflow does not occur when assuming that (X + c) < X is always false [-Wstrict-overflow]
#      for (i = 1; i < K; i++) {
#      ^~~
# cc -c -o OBJ/LinKernighan.o LinKernighan.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/LKHmain.o LKHmain.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Make2OptMove.o Make2OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Make3OptMove.o Make3OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Make4OptMove.o Make4OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Make5OptMove.o Make5OptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MakeKOptMove.o MakeKOptMove.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MergeTourWithBestTour.o MergeTourWithBestTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MergeWithTourIPT.o MergeWithTourIPT.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Minimum1TreeCost.o Minimum1TreeCost.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MinimumSpanningTree.o MinimumSpanningTree.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MTSP2TSP.o MTSP2TSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MTSP_InitialTour.o MTSP_InitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MTSP_Report.o MTSP_Report.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MTSP_WriteSolution.o MTSP_WriteSolution.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/NormalizeNodeList.o NormalizeNodeList.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/NormalizeSegmentList.o NormalizeSegmentList.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/OrderCandidateSet.o OrderCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/PatchCycles.o PatchCycles.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_ACVRP.o Penalty_ACVRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_BWTSP.o Penalty_BWTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_CCVRP.o Penalty_CCVRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_CVRP.o Penalty_CVRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_CVRPTW.o Penalty_CVRPTW.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_CTSP.o Penalty_CTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_1_PDTSP.o Penalty_1_PDTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_MLP.o Penalty_MLP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_M_PDTSP.o Penalty_M_PDTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_M1_PDTSP.o Penalty_M1_PDTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_MTSP.o Penalty_MTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_OVRP.o Penalty_OVRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_PDPTW.o Penalty_PDPTW.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_PDTSP.o Penalty_PDTSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_PDTSPF.o Penalty_PDTSPF.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_PDTSPL.o Penalty_PDTSPL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_RCTVRP.o Penalty_RCTVRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_SOP.o Penalty_SOP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_TRP.o Penalty_TRP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_TSPDL.o Penalty_TSPDL.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_TSPPD.o Penalty_TSPPD.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_TSPTW.o Penalty_TSPTW.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# In file included from Penalty_TSPTW.c:2:0:
# Penalty_TSPTW.c: In function ‘Penalty_TSPTW’:
# INCLUDE/Segment.h:63:21: warning: ‘NextN’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  #define SUCC(a) ((a)->Parent ? SUC(a) :\
#                      ^~
# Penalty_TSPTW.c:6:23: note: ‘NextN’ was declared here
#      Node *N = Depot, *NextN;
#                        ^~~~~
# cc -c -o OBJ/Penalty_VRPB.o Penalty_VRPB.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_VRPBTW.o Penalty_VRPBTW.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Penalty_VRPPD.o Penalty_VRPPD.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/PDPTW_Reduce.o PDPTW_Reduce.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/printff.o printff.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/PrintParameters.o PrintParameters.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Random.o Random.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ReadCandidates.o ReadCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ReadEdges.o ReadEdges.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# ReadEdges.c: In function ‘ReadEdges’:
# ReadEdges.c:31:9: warning: ignoring return value of ‘fscanf’, declared with attribute warn_unused_result [-Wunused-result]
#          fscanf(EdgeFile, "%d %d\n", &i, &Edges);
#          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ReadEdges.c:36:13: warning: ignoring return value of ‘fgets’, declared with attribute warn_unused_result [-Wunused-result]
#              fgets(line, 80, EdgeFile);
#              ^~~~~~~~~~~~~~~~~~~~~~~~~
# cc -c -o OBJ/ReadLine.o ReadLine.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ReadParameters.o ReadParameters.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ReadPenalties.o ReadPenalties.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ReadProblem.o ReadProblem.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# ReadProblem.c: In function ‘Read_EDGE_DATA_SECTION’:
# ReadProblem.c:1205:21: warning: ignoring return value of ‘fscanf’, declared with attribute warn_unused_result [-Wunused-result]
#                      fscanf(ProblemFile, "%lf", &w);
#                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -c -o OBJ/RecordBestTour.o RecordBestTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/RecordBetterTour.o RecordBetterTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/RemoveFirstActive.o RemoveFirstActive.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/ResetCandidateSet.o ResetCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/RestoreTour.o RestoreTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SegmentSize.o SegmentSize.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Sequence.o Sequence.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SFCTour.o SFCTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveCompressedSubproblem.o SolveCompressedSubproblem.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SINTEF_WriteSolution.o SINTEF_WriteSolution.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SOP_RepairTour.o SOP_RepairTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/STTSP2TSP.o STTSP2TSP.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveDelaunaySubproblems.o SolveDelaunaySubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveKarpSubproblems.o SolveKarpSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveKCenterSubproblems.o SolveKCenterSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveKMeansSubproblems.o SolveKMeansSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveRoheSubproblems.o SolveRoheSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveSFCSubproblems.o SolveSFCSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveSubproblem.o SolveSubproblem.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveSubproblemBorderProblems.o SolveSubproblemBorderProblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SolveTourSegmentSubproblems.o SolveTourSegmentSubproblems.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SOP_InitialTour.o SOP_InitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SOP_Report.o SOP_Report.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/StatusReport.o StatusReport.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/Statistics.o Statistics.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/StoreTour.o StoreTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/SymmetrizeCandidateSet.o SymmetrizeCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/TrimCandidateSet.o TrimCandidateSet.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/TSPDL_InitialTour.o TSPDL_InitialTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/TSPTW_MakespanCost.o TSPTW_MakespanCost.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/TSPTW_Reduce.o TSPTW_Reduce.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/VRPB_Reduce.o VRPB_Reduce.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/BIT.o BIT.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/WriteCandidates.o WriteCandidates.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/WritePenalties.o WritePenalties.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/WriteTour.o WriteTour.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/MergeWithTourGPX2.o MergeWithTourGPX2.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -c -o OBJ/gpx.o gpx.c -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g
# cc -o ../LKH OBJ/Activate.o OBJ/AddCandidate.o OBJ/AddExtraCandidates.o OBJ/AddTourCandidates.o OBJ/AdjustCandidateSet.o OBJ/AdjustClusters.o OBJ/AllocateStructures.o OBJ/Ascent.o OBJ/Best2OptMove.o OBJ/Best3OptMove.o OBJ/Best4OptMove.o OBJ/Best5OptMove.o OBJ/BestKOptMove.o OBJ/BestSpecialOptMove.o OBJ/Between.o OBJ/Between_SL.o OBJ/Between_SSL.o OBJ/BridgeGain.o OBJ/BuildKDTree.o OBJ/C.o OBJ/CandidateReport.o OBJ/ChooseInitialTour.o OBJ/Connect.o OBJ/CreateCandidateSet.o OBJ/CreateDelaunayCandidateSet.o OBJ/CreateNNCandidateSet.o OBJ/Create_POPMUSIC_CandidateSet.o OBJ/CreateQuadrantCandidateSet.o OBJ/CTSP_InitialTour.o OBJ/CVRP_InitialTour.o OBJ/Delaunay.o OBJ/Distance.o OBJ/Distance_MTSP.o OBJ/Distance_SOP.o OBJ/Distance_SPECIAL.o OBJ/eprintf.o OBJ/ERXT.o OBJ/Excludable.o OBJ/Exclude.o OBJ/FindTour.o OBJ/FixedOrCommonCandidates.o OBJ/Flip.o OBJ/Flip_SL.o OBJ/Flip_SSL.o OBJ/Forbidden.o OBJ/FreeStructures.o OBJ/fscanint.o OBJ/Gain23.o OBJ/GenerateCandidates.o OBJ/Genetic.o OBJ/GeoConversion.o OBJ/GetTime.o OBJ/GreedyTour.o OBJ/Hashing.o OBJ/Heap.o OBJ/Improvement.o OBJ/IsBackboneCandidate.o OBJ/IsCandidate.o OBJ/IsCommonEdge.o OBJ/IsPossibleCandidate.o OBJ/KSwapKick.o OBJ/LinKernighan.o OBJ/LKHmain.o OBJ/Make2OptMove.o OBJ/Make3OptMove.o OBJ/Make4OptMove.o OBJ/Make5OptMove.o OBJ/MakeKOptMove.o OBJ/MergeTourWithBestTour.o OBJ/MergeWithTourIPT.o OBJ/Minimum1TreeCost.o OBJ/MinimumSpanningTree.o OBJ/MTSP2TSP.o OBJ/MTSP_InitialTour.o OBJ/MTSP_Report.o OBJ/MTSP_WriteSolution.o OBJ/NormalizeNodeList.o OBJ/NormalizeSegmentList.o OBJ/OrderCandidateSet.o OBJ/PatchCycles.o OBJ/Penalty_ACVRP.o OBJ/Penalty_BWTSP.o OBJ/Penalty_CCVRP.o OBJ/Penalty_CVRP.o OBJ/Penalty_CVRPTW.o OBJ/Penalty_CTSP.o OBJ/Penalty_1_PDTSP.o OBJ/Penalty_MLP.o OBJ/Penalty_M_PDTSP.o OBJ/Penalty_M1_PDTSP.o OBJ/Penalty_MTSP.o OBJ/Penalty_OVRP.o OBJ/Penalty_PDPTW.o OBJ/Penalty_PDTSP.o OBJ/Penalty_PDTSPF.o OBJ/Penalty_PDTSPL.o OBJ/Penalty_RCTVRP.o OBJ/Penalty_SOP.o OBJ/Penalty_TRP.o OBJ/Penalty_TSPDL.o OBJ/Penalty_TSPPD.o OBJ/Penalty_TSPTW.o OBJ/Penalty_VRPB.o OBJ/Penalty_VRPBTW.o OBJ/Penalty_VRPPD.o OBJ/PDPTW_Reduce.o OBJ/printff.o OBJ/PrintParameters.o OBJ/Random.o OBJ/ReadCandidates.o OBJ/ReadEdges.o OBJ/ReadLine.o OBJ/ReadParameters.o OBJ/ReadPenalties.o OBJ/ReadProblem.o OBJ/RecordBestTour.o OBJ/RecordBetterTour.o OBJ/RemoveFirstActive.o OBJ/ResetCandidateSet.o OBJ/RestoreTour.o OBJ/SegmentSize.o OBJ/Sequence.o OBJ/SFCTour.o OBJ/SolveCompressedSubproblem.o OBJ/SINTEF_WriteSolution.o OBJ/SOP_RepairTour.o OBJ/STTSP2TSP.o OBJ/SolveDelaunaySubproblems.o OBJ/SolveKarpSubproblems.o OBJ/SolveKCenterSubproblems.o OBJ/SolveKMeansSubproblems.o OBJ/SolveRoheSubproblems.o OBJ/SolveSFCSubproblems.o OBJ/SolveSubproblem.o OBJ/SolveSubproblemBorderProblems.o OBJ/SolveTourSegmentSubproblems.o OBJ/SOP_InitialTour.o OBJ/SOP_Report.o OBJ/StatusReport.o OBJ/Statistics.o OBJ/StoreTour.o OBJ/SymmetrizeCandidateSet.o OBJ/TrimCandidateSet.o OBJ/TSPDL_InitialTour.o OBJ/TSPTW_MakespanCost.o OBJ/TSPTW_Reduce.o OBJ/VRPB_Reduce.o OBJ/BIT.o OBJ/WriteCandidates.o OBJ/WritePenalties.o OBJ/WriteTour.o OBJ/MergeWithTourGPX2.o OBJ/gpx.o -O3 -Wall -IINCLUDE -DTWO_LEVEL_TREE -g -lm
# make[2]: Leaving directory '/content/LKH-3.0.6/SRC'
# make[1]: Leaving directory '/content/LKH-3.0.6/SRC'

# %%
# !sudo cp LKH /usr/local/bin

# %%
pip install lkh --upgrade
# Out:
# Collecting lkh
#   Downloading https://files.pythonhosted.org/packages/29/a4/6c53f38453abe6982414dee166f066aa88ac790f7f33e782a69cdca5e542/lkh-1.0.4.tar.gz
# Collecting tsplib95
#   Downloading https://files.pythonhosted.org/packages/a0/2b/b1932d3674758ec5f49afa72d4519334a5ac2aac4d96cfd416eb872a1959/tsplib95-0.7.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: tabulate~=0.8.7 in /usr/local/lib/python3.7/dist-packages (from tsplib95->lkh) (0.8.9)
# Collecting Deprecated~=1.2.9
#   Downloading https://files.pythonhosted.org/packages/fb/73/994edfcba74443146c84b91921fcc269374354118d4f452fb0c54c1cbb12/Deprecated-1.2.12-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from tsplib95->lkh) (7.1.2)
# Requirement already satisfied, skipping upgrade: networkx~=2.1 in /usr/local/lib/python3.7/dist-packages (from tsplib95->lkh) (2.5.1)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from Deprecated~=1.2.9->tsplib95->lkh) (1.12.1)
# Requirement already satisfied, skipping upgrade: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx~=2.1->tsplib95->lkh) (4.4.2)
# Building wheels for collected packages: lkh
#   Building wheel for lkh (setup.py) ... done
#   Created wheel for lkh: filename=lkh-1.0.4-cp37-none-any.whl size=2826 sha256=2028c8df8c17ec8de7dae30b721f4a69cda7910f6683187ce18481a99eca5ccd
#   Stored in directory: /root/.cache/pip/wheels/7d/d1/ce/464306ccfc6d630b58cb596bd932b3a34a8b16ec521ac6a9c7
# Successfully built lkh
# Installing collected packages: Deprecated, tsplib95, lkh
# Successfully installed Deprecated-1.2.12 lkh-1.0.4 tsplib95-0.7.1

# %%
cd ..
# Out:
# /content

# %%
pip install ortools
# Out:
# Collecting ortools
#   Downloading https://files.pythonhosted.org/packages/6a/bd/75277072925d687aa35a6ea9e23e81a7f6b7c980b2a80949c5b9a3f98c79/ortools-9.0.9048-cp37-cp37m-manylinux1_x86_64.whl (14.4MB)
#      |████████████████████████████████| 14.4MB 281kB/s
# Collecting protobuf>=3.15.8
#   Downloading https://files.pythonhosted.org/packages/4c/53/ddcef00219f2a3c863b24288e24a20c3070bd086a1e77706f22994a7f6db/protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 21.7MB/s
# Requirement already satisfied: absl-py>=0.11 in /usr/local/lib/python3.7/dist-packages (from ortools) (0.12.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.15.8->ortools) (1.15.0)
# ERROR: tensorflow 2.5.0 has requirement numpy~=1.19.2, but you'll have numpy 1.20.0 which is incompatible.
# Installing collected packages: protobuf, ortools
#   Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
# Successfully installed ortools-9.0.9048 protobuf-3.17.3

# %% [markdown]
# ## Prepare Input

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial import distance_matrix

plt.rcParams['axes.facecolor'] = '#ededed'

# %%
# !wget http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/ch130.tsp
# Out:
# --2021-06-09 12:51:46--  http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/ch130.tsp
# Resolving elib.zib.de (elib.zib.de)... 130.73.108.67
# Connecting to elib.zib.de (elib.zib.de)|130.73.108.67|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4386 (4.3K) [text/plain]
# Saving to: ‘ch130.tsp’
#
# ch130.tsp           100%[===================>]   4.28K  --.-KB/s    in 0.1s
#
# 2021-06-09 12:51:46 (39.7 KB/s) - ‘ch130.tsp’ saved [4386/4386]

# %%
data = open('ch130.tsp','r')

# %%
read = data.read()

# %%
cord = [list(map(float,i.split())) for i in read.split('\n')[6:-2]]

# %%
cord = np.array(cord)[:,1:]

# %%
matrix = distance_matrix(cord, cord)
#matrix = matrix * 111139

# %%
num_points = cord.shape[0]
num_points
# Out:
# 130

# %%
def cal_total_distance(route):
    '''The objective
     function. input routine, return total distance.
    cal_total_distance(np.arange(num_points))
    '''
    route = np.array(route)
    num_points, = route.shape
    return sum([matrix[route[i % num_points], route[(i + 1) % num_points]] for i in range(num_points)])

# %%
def plot_tsp(cord, best_points):
  best_points_ = np.concatenate([best_points, [best_points[0]]])
  best_points_coordinate = cord[best_points_, :]
  plt.plot(best_points_coordinate[:, 0], best_points_coordinate[:, 1],
           marker='o', markerfacecolor='b', color='c', linestyle='-')
  plt.title('Total Distance = '+str(cal_total_distance(best_points)))

# %% [markdown]
# # Simulated Annealing - Scikit Opt

# %%
from sko.SA import SA_TSP

# %% Plot the best routine
from matplotlib.ticker import FormatStrFormatter

# %%
sa_tsp = SA_TSP(func=cal_total_distance, x0=range(num_points), T_max=100, T_min=1, L=10*num_points)

# %%
#Time 
best_points, best_distance = sa_tsp.run()
print(best_distance)
# Out:
# 6633.259035795066

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,6))

best_points_ = np.concatenate([best_points, [best_points[0]]])
best_points_coordinate = cord[best_points_, :]
ax[0].plot(sa_tsp.best_y_history)
ax[0].set_xlabel("Iteration")
ax[0].set_ylabel("Distance")
ax[1].plot(best_points_coordinate[:, 0], best_points_coordinate[:, 1],
           marker='o', markerfacecolor='b', color='c', linestyle='-')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

best_x_history = sa_tsp.best_x_history
best_y_history = sa_tsp.best_y_history

fig2, ax2 = plt.subplots(1, 1)
ax2.set_title('title', loc='center')
line = ax2.plot(cord[:, 0], cord[:, 1],
                marker='o', markerfacecolor='b', color='c', linestyle='-')
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax2.set_xlabel("Longitude")
ax2.set_ylabel("Latitude")
plt.ion()
p = plt.show()


def update_scatter(frame):
    ax2.set_title('Iter = ' + str(frame)+', Total Length ='+ str(best_y_history[frame]))
    points = best_x_history[frame]
    points = np.concatenate([points, [points[0]]])
    point_coordinate = cord[points, :]
    plt.setp(line, 'xdata', point_coordinate[:, 0], 'ydata', point_coordinate[:, 1])
    return line


ani = FuncAnimation(fig2, update_scatter, blit=True, interval=30, frames=len(best_x_history))
plt.show()

# %%
ani.save('sa_tsp.gif', writer='pillow')

# %% [markdown]
# # LKH

# %%
import tsplib95
import lkh
import requests

# %%
problem_str = requests.get('http://elib.zib.de/pub/mp-testdata/tsp/tsplib/tsp/ch130.tsp').text
problem = tsplib95.parse(problem_str)

# %%
solver_path = 'LKH-3.0.6/LKH'
slkh = lkh.solve(solver_path, problem=problem, max_trials=10000, runs=10)

# %%
plot_tsp(cord, np.array(slkh[0])-1)

# %% [markdown]
# # 2 Opt - Py2opt

# %%
from py2opt.routefinder import RouteFinder

# %%
cities_names = range(num_points)
dist_mat = matrix
route_finder = RouteFinder(dist_mat, cities_names)
best_distance, best_route = route_finder.solve()
# Out:
# 0 msec
# 126 msec
# 254 msec
# 379 msec
# 506 msec

# %%
plot_tsp(cord, best_route)

# %% [markdown]
# ## OR-Tools

# %%
from ortools.constraint_solver import pywrapcp, routing_enums_pb2

# %%
manager = pywrapcp.RoutingIndexManager(len(matrix),1,0)
routing = pywrapcp.RoutingModel(manager)

# %%
def distance_callback(from_index, to_index):
    """Returns the distance between the two nodes."""
    # Convert from routing variable Index to distance matrix NodeIndex.
    from_node = manager.IndexToNode(from_index)
    to_node = manager.IndexToNode(to_index)
    return matrix[from_node][to_node]

transit_callback_index = routing.RegisterTransitCallback(distance_callback)

# %%
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# %%
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

# %%
def solve(manager, routing, solution):
    """Prints solution on console."""
    length = solution.ObjectiveValue()
    index = routing.Start(0)
    route = [] 
    while not routing.IsEnd(index):
        route.append(manager.IndexToNode(index))
        index = solution.Value(routing.NextVar(index))
    return {'route':route + [0], 'length':length}

# %%
solution = routing.SolveWithParameters(search_parameters)
output = solve(manager, routing, solution)

# %%
plot_tsp(cord, output['route'][:-1])
